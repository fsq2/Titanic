# %%
### READ THE README.md FILE

# %%
#import needed libarys 
import pandas as pd 
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from bokeh.plotting import figure, show, output_file
from mpl_toolkits.mplot3d import Axes3D


# %matplotlib inline

# %%
# ?sns.catplot();

# %%
titanic = pd.read_csv('train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# histogram for age to see distrbution of data 
titanic.Age.hist();

# %%
g = sns.FacetGrid(titanic, col='Survived')
g.map(plt.hist, 'Age', bins=60);

# %%
#check for the null value 
nullvalue=titanic.isnull().sum()
nullvalue
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# cabins has the must null value  687 empty cell
nullvalue.plot(kind='barh');
plt.ylabel('number of null value');
# plt.xticks(color='white');
# plt.yticks(color='white');

# %%
# see the coreltion using heatmap 
sns.heatmap(titanic.corr(),annot=True)
plt.yticks(rotation = 0);

# %%
# 3. Delete all rows where `Embarked` is empty
# titanic.Embarked= titanic['Embarked'].notnull() 
# instaed I replace  the null value  with S
titanic['Embarked'].fillna('S', inplace=True)
#replace the null value in Cabin with '**¯\\_(ツ)_/¯**'
titanic['Cabin'].fillna('**¯\\_(ツ)_/¯**', inplace=True)

# replace the Age null values 
titanic['Age'] = titanic.groupby(["Sex", 'Pclass'])["Age"]\
.transform(lambda x: x.fillna(x.mean()))

titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
sns.distplot(titanic['Age'],kde=True);

# %%
#two columns that pertain to how many family members are on the boat
titanic['FamilyCount'] = titanic.SibSp + titanic.Parch

# %%
# to find reverend in passengers  

# str.find will look if there any Rev in the name  and will use it like array index -1 if none Rev
titanic['IsReverend']=titanic['Name'].str.find('Rev')
# Replace -1 with zeros 
titanic.IsReverend =titanic.IsReverend.replace(-1,0)
# Look for rev and give them 1 
titanic['IsReverend'].values[titanic['IsReverend'].values > 0] = 1

# %%
# make dummy coulmns 
titanic = pd.get_dummies(titanic, columns=['Sex'])
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare          Cabin Embarked  FamilyCount  IsReverend  \
# 0         A/5 21171   7.2500  **¯\_(ツ)_/¯**        S            1           0
# 1          PC 17599  71.2833            C85        C            1           0
# 2  STON/O2. 3101282   7.9250  **¯\_(ツ)_/¯**        S            0           0
# 3            113803  53.1000           C123        S            1           0
# 4            373450   8.0500  **¯\_(ツ)_/¯**        S            0           0
#
#    Sex_female  Sex_male
# 0           0         1
# 1           1         0
# 2           1         0
# 3           1         0
# 4           0         1

# %%
# make dummy coulmns 
titanic = pd.get_dummies(titanic, columns=['Embarked'])
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare          Cabin  FamilyCount  IsReverend  \
# 0         A/5 21171   7.2500  **¯\_(ツ)_/¯**            1           0
# 1          PC 17599  71.2833            C85            1           0
# 2  STON/O2. 3101282   7.9250  **¯\_(ツ)_/¯**            0           0
# 3            113803  53.1000           C123            1           0
# 4            373450   8.0500  **¯\_(ツ)_/¯**            0           0
#
#    Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0           0         1           0           0           1
# 1           1         0           1           0           0
# 2           1         0           0           0           1
# 3           1         0           0           0           1
# 4           0         1           0           0           1

# %%
# # 1. What was the survival rate overall?

# surviulrate = titanic.Survived.sum() / len(titanic['Survived'])*100
# print(f'survival rate overall {surviulrate}%')

# %%
# create categories bassed on age
binss=[0, 5, 12, 18, 35, 60, 100]
label_names = ['Infant', "Child", 'Teenager', "Young Adult", 'Adult', 'Senior']
titanic['Age_group']= pd.cut(titanic.Age,bins=binss,labels=label_names)

# %%
# 
cage=titanic.pivot_table(index="Age_group",values="Survived")*100 
my_colors = 'rgbymc'  #red, green, blue, black, etc.
cage.plot(kind='bar',color=my_colors,legend=False);
plt.ylabel('Rate of Survive');
plt.xlabel('age groups');

# %%
# make dummy columns
titanic = pd.get_dummies(titanic, columns=['Age_group'])

# %%
# Functions that returns the title from a name. All the name in the dataset has the format "Surname, Title. Name"
def get_title(name):
    if '.' in name:
        return name.split(',')[1].split('.')[0].strip()
    else:
        return 'Unknown'


# Lets create a new column for the titles
titanic['Title'] = titanic['Name'].map(lambda x: get_title(x))
# make dummy columns
titanic = pd.get_dummies(titanic, columns=['Title'])

# %%
titanic.drop('Title_Rev',axis=1)
titanic.columns

# %%
# what was the survival rate ?
surviul_rate = titanic.Survived.sum() / len(titanic['Survived'])*100
print(f'the survival rate overall {surviul_rate}%')
# Out:
# the survival rate overall 38.38383838383838%

# %%
#which gender fared the worse ? male  with 18
sex_pivot=titanic.pivot_table(index="Sex_male",values="Survived") * 100
sex_pivot
# Out:
#            Survived
# Sex_male
# 0         74.203822
# 1         18.890815

# %%
# none of the rev survaived
titanic[(titanic.IsReverend ==1) & (titanic.Survived==1)]

# %%
# I think it`s not the ship captin  the titnic captin was Edward John Smith and he is not in the lis 
capt=titanic.loc[titanic['Title_Capt']==1]
capt
# Out:
#      PassengerId  Survived  Pclass                          Name   Age  SibSp  \
# 745          746         0       1  Crosby, Capt. Edward Gifford  70.0      1
#
#      Parch     Ticket  Fare Cabin         ...          Title_Master  \
# 745      1  WE/P 5735  71.0   B22         ...                     0
#
#      Title_Miss  Title_Mlle  Title_Mme  Title_Mr  Title_Mrs  Title_Ms  \
# 745           0           0          0         0          0         0
#
#      Title_Rev  Title_Sir  Title_the Countess
# 745          0          0                   0
#
# [1 rows x 40 columns]

# %%
# titanic.groupby('Sex_female')['Survived'].sum() / len(titanic['Survived'])*100
sx=pd.crosstab(titanic.Sex_female,titanic.Survived, normalize='index').mul(100)
sx
# Out:
# Survived            0          1
# Sex_female
# 0           81.109185  18.890815
# 1           25.796178  74.203822

# %%
classs =pd.crosstab(titanic.Pclass, titanic.Survived, normalize='index').mul(100)
classs
# ss=titanic.pivot_table(index="Pclass",values="Survived") * 100
# ss
# Out:
# Survived          0          1
# Pclass
# 1         37.037037  62.962963
# 2         52.717391  47.282609
# 3         75.763747  24.236253

# %%
# titanic.groupby('Cabin')['Survived'].sum() /len(titanic['Survived'])*100
pd.crosstab(titanic.Cabin, titanic.Survived, normalize='index').mul(100)
# Out:
# Survived                0           1
# Cabin
# **¯\_(ツ)_/¯**   70.014556   29.985444
# A10            100.000000    0.000000
# A14            100.000000    0.000000
# A16              0.000000  100.000000
# A19            100.000000    0.000000
# A20              0.000000  100.000000
# A23              0.000000  100.000000
# A24            100.000000    0.000000
# A26              0.000000  100.000000
# A31              0.000000  100.000000
# A32            100.000000    0.000000
# A34              0.000000  100.000000
# A36            100.000000    0.000000
# A5             100.000000    0.000000
# A6               0.000000  100.000000
# A7             100.000000    0.000000
# B101             0.000000  100.000000
# B102           100.000000    0.000000
# B18              0.000000  100.000000
# B19            100.000000    0.000000
# B20              0.000000  100.000000
# B22             50.000000   50.000000
# B28              0.000000  100.000000
# B3               0.000000  100.000000
# B30            100.000000    0.000000
# B35              0.000000  100.000000
# B37            100.000000    0.000000
# B38            100.000000    0.000000
# B39              0.000000  100.000000
# B4               0.000000  100.000000
# ...                   ...         ...
# E12              0.000000  100.000000
# E121             0.000000  100.000000
# E17              0.000000  100.000000
# E24              0.000000  100.000000
# E25              0.000000  100.000000
# E31            100.000000    0.000000
# E33              0.000000  100.000000
# E34              0.000000  100.000000
# E36              0.000000  100.000000
# E38            100.000000    0.000000
# E40              0.000000  100.000000
# E44             50.000000   50.000000
# E46            100.000000    0.000000
# E49              0.000000  100.000000
# E50              0.000000  100.000000
# E58            100.000000    0.000000
# E63            100.000000    0.000000
# E67             50.000000   50.000000
# E68              0.000000  100.000000
# E77            100.000000    0.000000
# E8               0.000000  100.000000
# F E69            0.000000  100.000000
# F G63          100.000000    0.000000
# F G73          100.000000    0.000000
# F2              33.333333   66.666667
# F33              0.000000  100.000000
# F38            100.000000    0.000000
# F4               0.000000  100.000000
# G6              50.000000   50.000000
# T              100.000000    0.000000
#
# [148 rows x 2 columns]

# %%
pd.crosstab(titanic.Age, titanic.Survived, normalize='index').mul(100)
# Out:
# Survived           0           1
# Age
# 0.42        0.000000  100.000000
# 0.67        0.000000  100.000000
# 0.75        0.000000  100.000000
# 0.83        0.000000  100.000000
# 0.92        0.000000  100.000000
# 1.00       28.571429   71.428571
# 2.00       70.000000   30.000000
# 3.00       16.666667   83.333333
# 4.00       30.000000   70.000000
# 5.00        0.000000  100.000000
# 6.00       33.333333   66.666667
# 7.00       66.666667   33.333333
# 8.00       50.000000   50.000000
# 9.00       75.000000   25.000000
# 10.00     100.000000    0.000000
# 11.00      75.000000   25.000000
# 12.00       0.000000  100.000000
# 13.00       0.000000  100.000000
# 14.00      50.000000   50.000000
# 14.50     100.000000    0.000000
# 15.00      20.000000   80.000000
# 16.00      64.705882   35.294118
# 17.00      53.846154   46.153846
# 18.00      65.384615   34.615385
# 19.00      64.000000   36.000000
# 20.00      80.000000   20.000000
# 20.50     100.000000    0.000000
# 21.00      79.166667   20.833333
# 21.75      40.476190   59.523810
# 22.00      59.259259   40.740741
# ...              ...         ...
# 44.00      66.666667   33.333333
# 45.00      58.333333   41.666667
# 45.50     100.000000    0.000000
# 46.00     100.000000    0.000000
# 47.00      88.888889   11.111111
# 48.00      33.333333   66.666667
# 49.00      33.333333   66.666667
# 50.00      50.000000   50.000000
# 51.00      71.428571   28.571429
# 52.00      50.000000   50.000000
# 53.00       0.000000  100.000000
# 54.00      62.500000   37.500000
# 55.00      50.000000   50.000000
# 55.50     100.000000    0.000000
# 56.00      50.000000   50.000000
# 57.00     100.000000    0.000000
# 58.00      40.000000   60.000000
# 59.00     100.000000    0.000000
# 60.00      50.000000   50.000000
# 61.00     100.000000    0.000000
# 62.00      50.000000   50.000000
# 63.00       0.000000  100.000000
# 64.00     100.000000    0.000000
# 65.00     100.000000    0.000000
# 66.00     100.000000    0.000000
# 70.00     100.000000    0.000000
# 70.50     100.000000    0.000000
# 71.00     100.000000    0.000000
# 74.00     100.000000    0.000000
# 80.00       0.000000  100.000000
#
# [94 rows x 2 columns]

# %%
help(pd.crosstab)
# Out:
# Help on function crosstab in module pandas.core.reshape.pivot:
#
# crosstab(index, columns, values=None, rownames=None, colnames=None, aggfunc=None, margins=False, margins_name='All', dropna=True, normalize=False)
#     Compute a simple cross-tabulation of two (or more) factors. By default
#     computes a frequency table of the factors unless an array of values and an
#     aggregation function are passed
#
#     Parameters
#     ----------
#     index : array-like, Series, or list of arrays/Series
#         Values to group by in the rows
#     columns : array-like, Series, or list of arrays/Series
#         Values to group by in the columns
#     values : array-like, optional
#         Array of values to aggregate according to the factors.
#         Requires `aggfunc` be specified.
#     aggfunc : function, optional
#         If specified, requires `values` be specified as well
#     rownames : sequence, default None
#         If passed, must match number of row arrays passed
#     colnames : sequence, default None
#         If passed, must match number of column arrays passed
#     margins : boolean, default False
#         Add row/column margins (subtotals)
#     margins_name : string, default 'All'
#         Name of the row / column that will contain the totals
#         when margins is True.
#
#         .. versionadded:: 0.21.0
#
#     dropna : boolean, default True
#         Do not include columns whose entries are all NaN
#     normalize : boolean, {'all', 'index', 'columns'}, or {0,1}, default False
#         Normalize by dividing all values by the sum of values.
#
#         - If passed 'all' or `True`, will normalize over all values.
#         - If passed 'index' will normalize over each row.
#         - If passed 'columns' will normalize over each column.
#         - If margins is `True`, will also normalize margin values.
#
#         .. versionadded:: 0.18.1
#
#
#     Notes
#     -----
#     Any Series passed will have their name attributes used unless row or column
#     names for the cross-tabulation are specified.
#
#     Any input passed containing Categorical data will have **all** of its
#     categories included in the cross-tabulation, even if the actual data does
#     not contain any instances of a particular category.
#
#     In the event that there aren't overlapping indexes an empty DataFrame will
#     be returned.
#
#     Examples
#     --------
#     >>> a = np.array(["foo", "foo", "foo", "foo", "bar", "bar",
#     ...               "bar", "bar", "foo", "foo", "foo"], dtype=object)
#     >>> b = np.array(["one", "one", "one", "two", "one", "one",
#     ...               "one", "two", "two", "two", "one"], dtype=object)
#     >>> c = np.array(["dull", "dull", "shiny", "dull", "dull", "shiny",
#     ...               "shiny", "dull", "shiny", "shiny", "shiny"],
#     ...               dtype=object)
#
#     >>> pd.crosstab(a, [b, c], rownames=['a'], colnames=['b', 'c'])
#     ... # doctest: +NORMALIZE_WHITESPACE
#     b   one        two
#     c   dull shiny dull shiny
#     a
#     bar    1     2    1     0
#     foo    2     2    1     2
#
#     >>> foo = pd.Categorical(['a', 'b'], categories=['a', 'b', 'c'])
#     >>> bar = pd.Categorical(['d', 'e'], categories=['d', 'e', 'f'])
#     >>> crosstab(foo, bar)  # 'c' and 'f' are not represented in the data,
#     ...                     # but they still will be counted in the output
#     ... # doctest: +SKIP
#     col_0  d  e  f
#     row_0
#     a      1  0  0
#     b      0  1  0
#     c      0  0  0
#
#     Returns
#     -------
#     crosstab : DataFrame

# %%
n =pd.crosstab([titanic.Embarked_C, titanic.Embarked_Q,titanic.Embarked_S], titanic.Survived ,normalize='index').mul(100)
n
# Out:
# Survived                                  0          1
# Embarked_C Embarked_Q Embarked_S
# 0          0          1           66.099071  33.900929
#            1          0           61.038961  38.961039
# 1          0          0           44.642857  55.357143

# %%
under12 = titanic[titanic['Age']< 12].groupby('Pclass')['Survived'].sum()/titanic[titanic['Age']< 12].groupby('Pclass')['PassengerId'].count() * 100
under12
# Out:
# Pclass
# 1     75.000000
# 2    100.000000
# 3     40.425532
# dtype: float64

# %%
titanic[titanic['Survived']==0].sort_values('Fare', ascending=False)
print(' Mr. Charles Alexander had ticket cost 263.0000  and die ):')
# Out:
#  Mr. Charles Alexander had ticket cost 263.0000  and die ):

# %%
survivalRateByFamily = titanic.groupby('FamilyCount')['Survived'].sum()/titanic[titanic['FamilyCount']>=1].groupby('FamilyCount')['PassengerId'].count() * 100
survivalRateByFamily
# Out:
# FamilyCount
# 0           NaN
# 1     55.279503
# 2     57.843137
# 3     72.413793
# 4     20.000000
# 5     13.636364
# 6     33.333333
# 7      0.000000
# 10     0.000000
# dtype: float64

# %%
survivalRatewithoutFamily = titanic.groupby('FamilyCount')['Survived'].sum()/titanic[titanic['FamilyCount']==0].groupby('FamilyCount')['PassengerId'].count() * 100
survivalRatewithoutFamily
# Out:
# FamilyCount
# 0     30.353818
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 10          NaN
# dtype: float64

# %%
classs.plot(kind='barh');
plt.title('Survaival Rate for each class')
plt.ylabel('Classes');
plt.xlabel('Survaival Rate ');

# plt.xticks(color='white');
# plt.yticks(color='white');

# %%
ageclass = sns.FacetGrid(titanic, hue='Survived', aspect=3, legend_out=True)
ageclass.map(sns.kdeplot, "Age", shade=True).add_legend()
ageclass.set(xlim=(0, 80));

# %%
s = titanic.groupby('FamilyCount')['Survived'].sum()/titanic.groupby('FamilyCount')['PassengerId'].count() * 100

plt.title('chances of survival by family');
plt.xlabel('Rate of survival')
plt.ylabel('family  count')

# plt.xticks(color='white')
# plt.yticks(color='white')


s.plot(kind='barh',figsize=(12,8));

# %%
under12.plot(kind='barh',figsize=(12,8));
plt.title('survival under 12 by class');
plt.xlabel('Rate of survival')
plt.ylabel('Class')

# plt.xticks(color='white')
# plt.yticks(color='white');
# Out:
# Text(0,0.5,'Class')

# %%
titanic.groupby('Survived')['Sex_female'].sum().plot(kind='bar')

plt.xticks(rotation=0);
sx.plot(kind='bar')
plt.xticks(rotation=0);
plt.title('survival by gender ',color='k');
plt.xlabel('Gender 0=male ,1=female',color='k')
plt.ylabel('survival rate')

# plt.xticks(color='white')
# plt.yticks(color='white');
# Out:
# Text(0,0.5,'survival rate')

# %%
titanic.groupby('Survived')['Embarked_C','Embarked_S' ,'Embarked_Q'].sum().plot(kind='bar')
plt.xticks(rotation=0);
n.plot(kind='barh')

# %%
titanic['Fare'].skew()
# Out:
# 4.787316519674893

# %%
titanic.corr()
# Out:
#                        PassengerId  Survived    Pclass       Age     SibSp  \
# PassengerId               1.000000 -0.005007 -0.035144  0.039636 -0.057527
# Survived                 -0.005007  1.000000 -0.338481 -0.067485 -0.035322
# Pclass                   -0.035144 -0.338481  1.000000 -0.407015  0.083081
# Age                       0.039636 -0.067485 -0.407015  1.000000 -0.251313
# SibSp                    -0.057527 -0.035322  0.083081 -0.251313  1.000000
# Parch                    -0.001652  0.081629  0.018443 -0.180705  0.414838
# Fare                      0.012658  0.257307 -0.549500  0.118308  0.159651
# FamilyCount              -0.040143  0.016639  0.065997 -0.262041  0.890712
# Age_group_Young Adult -0.245719 -0.134181    -0.197176   -0.040589
# Age_group_Adult        0.040882  0.141883    -0.046114    0.081511
# Age_group_Senior      -0.021502  0.029368    -0.048892   -0.013101
# Title_Capt             0.025731  0.026184     0.022770   -0.002760
# Title_Col             -0.022467 -0.001126    -0.026608   -0.003905
# Title_Don             -0.015878 -0.003026    -0.018804   -0.002760
# Title_Dr              -0.042150  0.030395    -0.018386   -0.007327
# Title_Jonkheer        -0.015878 -0.021735    -0.018804   -0.002760
# Title_Lady            -0.015878  0.004992     0.001983   -0.002760
# Title_Major           -0.022467 -0.003514    -0.026608   -0.003905
# Title_Master           0.267344  0.010908     0.372472   -0.017851
# Title_Miss             0.105567  0.118271     0.112838   -0.041717
# Title_Mlle            -0.022467  0.025974    -0.026608   -0.003905
# Title_Mme             -0.015878  0.025037    -0.018804   -0.002760
# Title_Mr              -0.333905 -0.183766    -0.338014   -0.096808
# Title_Mrs              0.225852  0.105203     0.156168   -0.033262
# Title_Ms              -0.015878 -0.012961    -0.018804   -0.002760
# Title_Rev             -0.021967 -0.023031    -0.029170    1.000000
# Title_Sir             -0.015878  0.016687     0.001983   -0.002760
# Title_the Countess    -0.015878  0.036645    -0.018804   -0.002760
#
#                        Sex_female         ...          Title_Master  \
# PassengerId             -0.042939         ...             -0.026151
# Survived                 0.543351         ...              0.085221
# Pclass                  -0.131900         ...              0.082081
# Age                     -0.112851         ...             -0.368335
# SibSp                    0.114631         ...              0.349559
# Parch                    0.245489         ...              0.267344
# Fare                     0.182333         ...              0.010908
# FamilyCount              0.200988         ...              0.372472
# IsReverend              -0.060741         ...             -0.017851
# Sex_female               1.000000         ...             -0.159934
# Sex_male                -1.000000         ...              0.159934
# Embarked_C               0.082853         ...             -0.035225
# Embarked_Q               0.074115         ...              0.010478
# Embarked_S              -0.119224         ...              0.024264
# Age_group_Infant         0.059571         ...              0.525950
# Age_group_Child          0.031151         ...              0.389839
# Age_group_Teenager       0.098941         ...             -0.063306
# Age_group_Young Adult   -0.038709         ...             -0.209267
# Age_group_Adult         -0.033557         ...             -0.122642
# Age_group_Senior        -0.071958         ...             -0.034496
# Title_Capt              -0.024728         ...             -0.007267
# Title_Col               -0.034990         ...             -0.010283
# Title_Don               -0.024728         ...             -0.007267
# Title_Dr                -0.039034         ...             -0.019292
# Title_Jonkheer          -0.024728         ...             -0.007267
# Title_Lady               0.045439         ...             -0.007267
# Title_Major             -0.034990         ...             -0.010283
# Title_Master            -0.159934         ...              1.000000
# Title_Miss               0.686808         ...             -0.109844
# Title_Mlle               0.064296         ...             -0.010283
# Title_Mme                0.045439         ...             -0.007267
# Title_Mr                -0.867334         ...             -0.254903
# Title_Mrs                0.547600         ...             -0.087580
# Title_Ms                 0.045439         ...             -0.007267
# Title_Rev               -0.060741         ...             -0.017851
# Title_Sir               -0.024728         ...             -0.007267
# Title_the Countess       0.045439         ...             -0.007267
#
#                        Title_Miss  Title_Mlle  Title_Mme  Title_Mr  Title_Mrs
# Age_group_Child       -0.005695  -0.013990  -0.005695           -0.005695
# Age_group_Teenager    -0.009788  -0.024043  -0.009788           -0.009788
# Age_group_Young Adult  0.028707  -0.040589  -0.039140            0.028707
# Age_group_Adult       -0.018962   0.081511   0.059256           -0.018962
# Age_group_Senior      -0.005333  -0.013101  -0.005333           -0.005333
# Title_Capt            -0.001124  -0.002760  -0.001124           -0.001124
# Title_Col             -0.001590  -0.003905  -0.001590           -0.001590
# Title_Don             -0.001124  -0.002760  -0.001124           -0.001124
# Title_Dr              -0.002983  -0.007327  -0.002983           -0.002983
# Title_Jonkheer        -0.001124  -0.002760  -0.001124           -0.001124
# Title_Lady            -0.001124  -0.002760  -0.001124           -0.001124
# Title_Major           -0.001590  -0.003905  -0.001590           -0.001590
# Title_Master          -0.007267  -0.017851  -0.007267           -0.007267
# Title_Miss            -0.016983  -0.041717  -0.016983           -0.016983
# Title_Mlle            -0.001590  -0.003905  -0.001590           -0.001590
# Title_Mme             -0.001124  -0.002760  -0.001124           -0.001124
# Title_Mr              -0.039411  -0.096808  -0.039411           -0.039411
# Title_Mrs             -0.013541  -0.033262  -0.013541           -0.013541
# Title_Ms               1.000000  -0.002760  -0.001124           -0.001124
# Title_Rev             -0.002760   1.000000  -0.002760           -0.002760
# Title_Sir             -0.001124  -0.002760   1.000000           -0.001124
# Title_the Countess    -0.001124  -0.002760  -0.001124            1.000000
#
# [37 rows x 37 columns]

# %%
titanic['Fare'].kurt()
# Out:
# 33.39814088089868

# %%
titanic.std()
# Out:
# PassengerId              257.353842
# Survived                   0.486592
# Pclass                     0.836071
# Age                       13.281103
# SibSp                      1.102743
# Parch                      0.806057
# Fare                      49.693429
# FamilyCount                1.613459
# IsReverend                 0.081830
# Sex_female                 0.477990
# Sex_male                   0.477990
# Embarked_C                 0.391372
# Embarked_Q                 0.281141
# Embarked_S                 0.446751
# Age_group_Infant           0.216787
# Age_group_Child            0.165232
# Age_group_Teenager         0.269207
# Age_group_Young Adult      0.494332
# Age_group_Adult            0.428790
# Age_group_Senior           0.155270
# Title_Capt                 0.033501
# Title_Col                  0.047351
# Title_Don                  0.033501
# Title_Dr                   0.088337
# Title_Jonkheer             0.033501
# Title_Lady                 0.033501
# Title_Major                0.047351
# Title_Master               0.207186
# Title_Miss                 0.403390
# Title_Mlle                 0.047351
# Title_Mme                  0.033501
# Title_Mr                   0.493796
# Title_Mrs                  0.347485
# Title_Ms                   0.033501
# Title_Rev                  0.081830
# Title_Sir                  0.033501
# Title_the Countess         0.033501
# dtype: float64

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.318643    0.523008
# std     257.353842    0.486592    0.836071   13.281103    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   21.750000    0.000000
# 50%     446.000000    0.000000    3.000000   26.507589    0.000000
# 75%     668.500000    1.000000    3.000000   36.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  FamilyCount  IsReverend  Sex_female  \
# count  891.000000  891.000000   891.000000  891.000000  891.000000
# mean     0.381594   32.204208     0.904602    0.006734    0.352413
# std      0.806057   49.693429     1.613459    0.081830    0.477990
# min      0.000000    0.000000     0.000000    0.000000    0.000000
# 25%
# 819  10.0      3      2       347088   27.9000  **¯\_(ツ)_/¯**
# 480   9.0      5      2      CA 2144   46.9000  **¯\_(ツ)_/¯**
# 852   9.0      1      1         2678   15.2458  **¯\_(ツ)_/¯**
# 147   9.0      2      2   W./C. 6608   34.3750  **¯\_(ツ)_/¯**
# 541   9.0      4      2       347082   31.2750  **¯\_(ツ)_/¯**
# 182   9.0      4      2       347077   31.3875  **¯\_(ツ)_/¯**
# 634   9.0      3      2       347088   27.9000  **¯\_(ツ)_/¯**
# 787   8.0      4      1       382652   29.1250  **¯\_(ツ)_/¯**
# 24    8.0      3      1       349909   21.0750  **¯\_(ツ)_/¯**
# 278   7.0      4      1       382652   29.1250  **¯\_(ツ)_/¯**
# 50    7.0      4      1      3101295   39.6875  **¯\_(ツ)_/¯**
# 813   6.0      4      2       347082   31.2750  **¯\_(ツ)_/¯**
# 63    4.0      3      2       347088   27.9000  **¯\_(ツ)_/¯**
# 171   4.0      4      1       382652   29.1250  **¯\_(ツ)_/¯**
# 850   4.0      4      2       347082   31.2750  **¯\_(ツ)_/¯**
# 374   3.0      3      1       349909   21.0750  **¯\_(ツ)_/¯**
# 7     2.0      3      1       349909   21.0750  **¯\_(ツ)_/¯**
# 205   2.0      0      1       347054   10.4625             G6
# 16    2.0      4      1       382652   29.1250  **¯\_(ツ)_/¯**
# 824   2.0      4      1      3101295   39.6875  **¯\_(ツ)_/¯**
# 297   2.0      1      2       113781  151.5500        C22 C26
# 642   2.0      3      2       347088   27.9000  **¯\_(ツ)_/¯**
# 119   2.0      4      2       347082   31.2750  **¯\_(ツ)_/¯**
# 386   1.0      5      2      CA 2144   46.9000  **¯\_(ツ)_/¯**
# 164   1.0      4      1      3101295   39.6875  **¯\_(ツ)_/¯**
#
#             ...          Title_Master  Title_Miss  Title_Mlle  Title_Mme  \
# 851         ...                     0           0           0          0
# 493         ...                     0           0           0          0
# 96          ...                     0           0           0          0
# 116         ...                     0           0           0          0
# 745         ...                     0           0           0          0
# 672         ...                     0           0           0          0
# 33          ...                     0           0           0          0
# 456         ...                     0           0           0          0
# 54          ...                     0           0           0          0
# 280         ...                     0           0           0          0
# 545         ...                     0           0           0          0
# 438         ...                     0           0           0          0
# 555         ...                     0           0           0          0
# 252         ...                     0           0           0          0
# 170         ...                     0           0           0          0
# 625         ...                     0           0           0          0
# 326         ...                     0           0           0          0
# 694         ...                     0           0           0          0
# 684         ...                     0           0           0          0
# 94          ...                     0           0           0          0
# 232         ...                     0           0           0          0
# 659         ...                     0           0           0          0
# 487         ...                     0           0           0          0
# 626         ...                     0           0           0          0
# 772         ...                     0           0           0          0
# 467         ...                     0           0           0          0
# 174         ...                     0           0           0          0
# 152         ...                     0           0           0          0
# 492         ...                     0           0           0          0
# 6           ...                     0           0           0          0
# ..          ...                   ...         ...         ...        ...
# 686         ...                     0           0           0          0
# 731         ...                     0           0           0          0
# 59          ...                     1           0           0          0
# 542         ...                     0           1           0          0
# 419         ...                     0           1           0          0
# 819         ...                     1           0           0          0
# 480         ...                     1           0           0          0
# 852         ...                     0           1           0          0
# 261                  Asplund, Master. Edvin Rojj Felix   3.00      4      2
# 530                           Quick, Miss. Phyllis May   2.00      1      1
# 479                           Hirvonen, Miss. Hildur E   2.00      0      1
# 340                     Navratil, Master. Edmond Roger   2.00      1      1
# 788                         Dean, Master. Bertram Vere   1.00      1      2
# 827                              Mallet, Master. Andre   1.00      0      2
# 381                        Nakid, Miss. Maria ("Mary")   1.00      0      2
# 172                       Johnson, Miss. Eleanor Ileen   1.00      1      1
# 183                          Becker, Master. Richard F   1.00      2      1
# 305                     Allison, Master. Hudson Trevor   0.92      1      2
# 78                       Caldwell, Master. Alden Gates   0.83      0      2
# 831                    Richards, Master. George Sibley   0.83      1      1
# 469                      Baclini, Miss. Helene Barbara   0.75      2      1
# 644                             Baclini, Miss. Eugenie   0.75      2      1
# 755                          Hamalainen, Master. Viljo   0.67      1      1
# 803                    Thomas, Master. Assad Alexander   0.42      0      1
#
#               Ticket      Fare          Cabin         ...          \
# 630            27042   30.0000            A23         ...
# 275            13502   77.9583             D7         ...
# 483             4134    9.5875  **¯\_(ツ)_/¯**         ...
# 829           113572   80.0000            B28         ...
# 570      S.W./PP 752   10.5000  **¯\_(ツ)_/¯**         ...
# 366           110813   75.2500            D37         ...
# 587            13567   79.2000            B41         ...
# 268         PC 17582  153.4625           C125         ...
# 11            113783   26.5500           C103         ...
# 195         PC 17569  146.5208            B80         ...
# 647            13213   35.5000            A26         ...
# 879            11767   83.1583            C50         ...
# 15            248706   16.0000  **¯\_(ツ)_/¯**         ...
# 496            36947   78.2667            D20         ...
# 513         PC 17603   59.4000  **¯\_(ツ)_/¯**         ...
# 774            29105   23.0000  **¯\_(ツ)_/¯**         ...
# 571            11769   51.4792           C101         ...
# 820            12749   93.5000            B69         ...
# 449           113786   30.5000           C104         ...
# 591            36947   78.2667            D20         ...
# 765            13502   77.9583            D11         ...
# 857           113055   26.5500            E17         ...
# 299         PC 17558  247.5208        B58 B60         ...
# 526      W./C. 14258   10.5000  **¯\_(ツ)_/¯**         ...
# 259           230433   26.0000  **¯\_(ツ)_/¯**         ...
# 458     F.C.C. 13531   10.5000  **¯\_(ツ)_/¯**         ...
# 660         PC 17611  133.6500  **¯\_(ツ)_/¯**         ...
# 599         PC 17485   56.9292            A20         ...
# 52          PC 17572   76.7292            D33         ...
# 453            17453   89.1042            C92         ...
# ..               ...       ...            ...         ...
# 448             2666   19.2583  **¯\_(ツ)_/¯**         ...
# 58        C.A. 34651   27.7500  **¯\_(ツ)_/¯**         ...
# 777           364516   12.4750  **¯\_(ツ)_/¯**         ...
# 750            29103   23.0000  **¯\_(ツ)_/¯**         ...
# 184           315153   22.0250  **¯\_(ツ)_/¯**         ...
# 445            33638   81.8583            A34         ...
# 691           349256   13.4167  **¯\_(ツ)_/¯**         ...
# 618           230136   39.0000             F4         ...
# 869           347742   11.1333  **¯\_(ツ)_/¯**         ...
# 10           PP 9549   16.7000             G6         ...
# 43     SC/Paris 2123   41.5792  **¯\_(ツ)_/¯**         ...
# 348       C.A. 37671   15.9000  **¯\_(ツ)_/¯**         ...
# 407            29106   18.7500  **¯\_(ツ)_/¯**         ...
# 483         0          0          0                   0
# 829         0          0          0                   0
# 570         0          0          0                   0
# 366         0          0          0                   0
# 587         0          0          0                   0
# 268         0          0          0                   0
# 11          0          0          0                   0
# 195         0          0          0                   0
# 647         0          0          0                   0
# 879         0          0          0                   0
# 15          0          0          0                   0
# 496         0          0          0                   0
# 513         0          0          0                   0
# 774         0          0          0                   0
# 571         0          0          0                   0
# 820         0          0          0                   0
# 449         0          0          0                   0
# 591         0          0          0                   0
# 765         0          0          0                   0
# 857         0          0          0                   0
# 299         0          0          0                   0
# 526         0          0          0                   0
# 259         0          0          0                   0
# 458         0          0          0                   0
# 660         0          0          0                   0
# 599         0          0          1                   0
# 52          0          0          0                   0
# 453         0          0          0                   0
# ..        ...        ...        ...                 ...
# 448         0          0          0                   0
# 58          0          0          0                   0
# 777         0          0          0                   0
# 750         0          0          0                   0
# 184         0          0          0                   0
# 445         0          0          0                   0
# 691         0          0          0                   0
# 618         0          0          0                   0
# 869         0          0          0                   0
# 10          0          0          0                   0
# 43          0          0          0                   0
# 348         0          0          0                   0
# 407         0          0          0                   0
# 193         0          0          0                   0
# 261         0          0          0                   0
# 530         0          0          0                   0
# 479         0          0          0                   0
# 340         0          0          0                   0
# 788         0          0          0                   0
# 827         0          0          0                   0
# 381         0          0          0                   0
# 172         0          0          0                   0
# 183         0          0          0                   0
# 305         0          0          0                   0
# 78          0          0          0                   0
# 831         0          0          0                   0
# 469         0          0          0                   0
# 644         0          0          0                   0
# 755         0          0          0                   0
# 803         0          0          0                   0
#
# [342 rows x 40 columns]

# %%
titanic.groupby('Survived')['Age'].max().plot(kind='bar',figsize=(12,8));

# %%
titanic.groupby('Survived')['Age'].min().plot(kind='bar',figsize=(12,8));

# %%
sns.violinplot(x=titanic.Sex_male, y=titanic.Age, hue="Survived", data=titanic,legend=False)

plt.legend(title='Survival', bbox_to_anchor=(1.05, 1),loc='upper left');

# %%
sns.violinplot(x=titanic.Pclass, y=titanic.Fare, hue=titanic.Survived, data=titanic);

# %%
titanic.groupby('Survived')['Embarked_S'].sum().plot(kind='pie',autopct='%1.1f%%');

# %%
titanic.groupby('Survived')['Embarked_C'].sum().plot(kind='pie',autopct='%1.1f%%');

# %%
titanic.groupby('Survived')['Embarked_Q'].sum().plot(kind='pie',autopct='%1.1f%%');

# %%
output_file('vbar.html')

p = figure(plot_width=400, plot_height=400)
p.vbar(x=titanic.Sex_male, width=0.5, bottom=0,
       top=titanic.Age, color="firebrick")

show(p)

# %%
sns.boxplot(x="Fare", y="Survived", data=titanic, orient='h');

# %%
sns.regplot(data=titanic,
         x=titanic.Age,
             y=titanic.Fare,scatter_kws={"color": "orange"}, line_kws={"color": "blue"});

# %%
g = sns.catplot("Pclass", 'Survived', "Sex_male", data=titanic, kind="bar")

# %%
sns.pointplot(x = "Sex_female", y = "Survived", hue = "Pclass", data = titanic);

# %%
sns.stripplot(x=titanic.Pclass,y=titanic.Fare,hue='Sex_male',jitter=True,data=titanic);

# %%
fare_to_survival = sns.FacetGrid(titanic, hue="Survived", aspect=2)
fare_to_survival.map(sns.kdeplot, "Fare", shade=True).add_legend()
fare_to_survival.set(xlim=(0, 550));

# %%
sns.pairplot(titanic);

# %%
sns.swarmplot(x ="Fare", y='Survived', data=titanic, orient='h', color='r',);
