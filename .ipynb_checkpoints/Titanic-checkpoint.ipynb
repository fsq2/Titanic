# %% [markdown]
# ### Titanic project
# ### author  Fahad Saeed alqahtani

# %%
#import needed libarys 
import pandas as pd 
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from bokeh.plotting import figure, show, output_file
from mpl_toolkits.mplot3d import Axes3D


# %matplotlib inline

# %% [markdown]
# ## Step 1: Cleaning the data

# %%
# ?sns.catplot();

# %%
titanic = pd.read_csv('train.csv')
# titanic.head()

# %%
# histogram for age to see distrbution of data 
titanic.Age.hist();

# %%
g = sns.FacetGrid(titanic, col='Survived')
g.map(plt.hist, 'Age', bins=60);

# %%
#check for the null value 
nullvalue=titanic.isnull().sum()
nullvalue
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# cabins has the must null value  687 empty cell
nullvalue.plot(kind='barh');
plt.ylabel('number of null value');
# plt.xticks(color='white');
# plt.yticks(color='white');

# %%
# see the coreltion using heatmap 
sns.heatmap(titanic.corr(),annot=True)
plt.yticks(rotation = 0);

# %%
# 3. Delete all rows where `Embarked` is empty
# titanic.Embarked= titanic['Embarked'].notnull() 
# instaed I replace  the null value  with S
titanic['Embarked'].fillna('S', inplace=True)
#replace the null value in Cabin with '**¯\\_(ツ)_/¯**'
titanic['Cabin'].fillna('**¯\\_(ツ)_/¯**', inplace=True)

# replace the Age null values 
titanic['Age'] = titanic.groupby(["Sex", 'Pclass'])["Age"]\
.transform(lambda x: x.fillna(x.mean()))

titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
sns.distplot(titanic['Age'],kde=True);

# %% [markdown]
# ## Step 2: Feature extraction

# %%
#two columns that pertain to how many family members are on the boat
titanic['FamilyCount'] = titanic.SibSp + titanic.Parch

# %%
# to find reverend in passengers  

# str.find will look if there any Rev in the name  and will use it like array index -1 if none Rev
titanic['IsReverend']=titanic['Name'].str.find('Rev')
# Replace -1 with zeros 
titanic.IsReverend =titanic.IsReverend.replace(-1,0)
# Look for rev and give them 1 
titanic['IsReverend'].values[titanic['IsReverend'].values > 0] = 1

# %%
# make dummy coulmns 
titanic = pd.get_dummies(titanic, columns=['Sex'])
titanic.filter(regex='Sex').head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare          Cabin Embarked  FamilyCount  IsReverend  \
# 0         A/5 21171   7.2500  **¯\_(ツ)_/¯**        S            1           0
# 1          PC 17599  71.2833            C85        C            1           0
# 2  STON/O2. 3101282   7.9250  **¯\_(ツ)_/¯**        S            0           0
# 3            113803  53.1000           C123        S            1           0
# 4            373450   8.0500  **¯\_(ツ)_/¯**        S            0           0
#
#    Sex_female  Sex_male
# 0           0         1
# 1           1         0
# 2           1         0
# 3           1         0
# 4           0         1

# %%
# make dummy coulmns 
titanic = pd.get_dummies(titanic, columns=['Embarked'])
titanic.filter(regex='Embarked').head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-474-8d4c9ac98be9> in <module>()
#       1 # make dummy coulmns
# ----> 2 titanic = pd.get_dummies(titanic, columns=['Embarked'])
#       3 titanic.filter(regex='Embarked').head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     830                 include=dtypes_to_encode)
#     831         else:
# --> 832             data_to_encode = data[columns]
#     833
#     834         # validate prefixes and separator to avoid silently dropping cols
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['Embarked'] not in index"

# %%
# # 1. What was the survival rate overall?

# surviulrate = titanic.Survived.sum() / len(titanic['Survived'])*100
# print(f'survival rate overall {surviulrate}%')

# %%
# create categories bassed on age
binss=[0, 5, 12, 18, 35, 60, 100]
label_names = ['Infant', "Child", 'Teenager', "Young Adult", 'Adult', 'Senior']
titanic['Age_group']= pd.cut(titanic.Age,bins=binss,labels=label_names)

# %%
#creat Age_group bar graph 
cage=titanic.pivot_table(index="Age_group",values="Survived")*100 
my_colors = 'rgbymc'  #red, green, blue, black, etc.
cage.plot(kind='bar',color=my_colors,legend=False);
plt.ylabel('Rate of Survive');
plt.xlabel('age groups');

# %%
# make dummy columns
titanic = pd.get_dummies(titanic, columns=['Age_group'])
titanic.filter(regex='Age_group').head()
# Out:
#    Age_group_Infant  Age_group_Child  Age_group_Teenager  \
# 0                 0                0                   0
# 1                 0                0                   0
# 2                 0                0                   0
# 3                 0                0                   0
# 4                 0                0                   0
#
#    Age_group_Young Adult  Age_group_Adult  Age_group_Senior
# 0                      1                0                 0
# 1                      0                1                 0
# 2                      1                0                 0
# 3                      1                0                 0
# 4                      1                0                 0

# %%
# Functions that returns the title from a name. All the name in the dataset has the format "Surname, Title. Name"
def get_title(name):
    if '.' in name:
        return name.split(',')[1].split('.')[0].strip()
    else:
        return 'Unknown'


# Lets create a new column for the titles
titanic['Title'] = titanic['Name'].map(lambda x: get_title(x))
# make dummy columns
titanic = pd.get_dummies(titanic, columns=['Title'])

# %%
# I have a column called IsReverend so no need for this column
titanic = titanic.drop('Title_Rev', 1)

# %% [markdown]
# ## Step 3: Exploratory analysis

# %%
# what was the survival rate ?
surviul_rate = titanic.Survived.sum() / len(titanic['Survived'])*100
print(f'the survival rate overall {surviul_rate}%')
# Out:
# the survival rate overall 38.38383838383838%

# %%
#which gender fared the worse ? male  with 18.89%
sex_pivot=titanic.pivot_table(index="Sex_male",values="Survived") * 100
sex_pivot
# Out:
#            Survived
# Sex_male
# 0         74.203822
# 1         18.890815

# %%
# another way to check
sx=pd.crosstab(titanic.Sex_female,titanic.Survived, normalize='index').mul(100)
sx
# Out:
# Survived            0          1
# Sex_female
# 0           81.109185  18.890815
# 1           25.796178  74.203822

# %%
# 3. What was the survival rate for each `Pclass`?

classs =pd.crosstab(titanic.Pclass, titanic.Survived, normalize='index').mul(100)[1]
classs
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: 1, dtype: float64

# %%
# another way to check 
ss=titanic.pivot_table(index="Pclass",values="Survived") * 100
ss
# Out:
#          Survived
# Pclass
# 1       62.962963
# 2       47.282609
# 3       24.236253

# %%
# none of the rev survaived
titanic[(titanic.IsReverend ==1) & (titanic.Survived==1)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Age, SibSp, Parch, Ticket, Fare, Cabin, FamilyCount, IsReverend, Sex_female, Sex_male, Embarked_C, Embarked_Q, Embarked_S, Age_group_Infant, Age_group_Child, Age_group_Teenager, Age_group_Young Adult, Age_group_Adult, Age_group_Senior, Title_Capt, Title_Col, Title_Don, Title_Dr, Title_Jonkheer, Title_Lady, Title_Major, Title_Master, Title_Miss, Title_Mlle, Title_Mme, Title_Mr, Title_Mrs, Title_Ms, Title_Sir, Title_the Countess]
# Index: []
#
# [0 rows x 39 columns]

# %%
# I think it`s not the ship captin  the titnic captin was Edward John Smith and he is not in the lis 
capt=titanic.loc[titanic['Title_Capt']==1]
capt
# Out:
#      PassengerId  Survived  Pclass                          Name   Age  SibSp  \
# 745          746         0       1  Crosby, Capt. Edward Gifford  70.0      1
#
#      Parch     Ticket  Fare Cabin         ...          Title_Major  \
# 745      1  WE/P 5735  71.0   B22         ...                    0
#
#      Title_Master  Title_Miss  Title_Mlle  Title_Mme  Title_Mr  Title_Mrs  \
# 745             0           0           0          0         0          0
#
#      Title_Ms  Title_Sir  Title_the Countess
# 745         0          0                   0
#
# [1 rows x 39 columns]

# %%
# 5. What is the survival rate for cabins marked **¯\\_(ツ)_/¯** ? 29.985444

pd.crosstab(titanic.Cabin, titanic.Survived, normalize='index').mul(100).head(1)[1]
# Out:
# Cabin
# **¯\_(ツ)_/¯**    29.985444
# Name: 1, dtype: float64

# %%
# 5. What is the survival rate for cabins marked **¯\\_(ツ)_/¯** ? 29.985444

cab=titanic.pivot_table(index="Cabin",values="Survived") * 100
cab
# Out:
#                  Survived
# Cabin
# **¯\_(ツ)_/¯**   29.985444
# A10              0.000000
# A14              0.000000
# A16            100.000000
# A19              0.000000
# A20            100.000000
# A23            100.000000
# A24              0.000000
# A26            100.000000
# A31            100.000000
# A32              0.000000
# A34            100.000000
# A36              0.000000
# A5               0.000000
# A6             100.000000
# A7               0.000000
# B101           100.000000
# B102             0.000000
# B18            100.000000
# B19              0.000000
# B20            100.000000
# B22             50.000000
# B28            100.000000
# B3             100.000000
# B30              0.000000
# B35            100.000000
# B37              0.000000
# B38              0.000000
# B39            100.000000
# B4             100.000000
# ...                   ...
# E12            100.000000
# E121           100.000000
# E17            100.000000
# E24            100.000000
# E25            100.000000
# E31              0.000000
# E33            100.000000
# E34            100.000000
# E36            100.000000
# E38              0.000000
# E40            100.000000
# E44             50.000000
# E46              0.000000
# E49            100.000000
# E50            100.000000
# E58              0.000000
# E63              0.000000
# E67             50.000000
# E68            100.000000
# E77              0.000000
# E8             100.000000
# F E69          100.000000
# F G63            0.000000
# F G73            0.000000
# F2              66.666667
# F33            100.000000
# F38              0.000000
# F4             100.000000
# G6              50.000000
# T                0.000000
#
# [148 rows x 1 columns]

# %%
# I replaced the null value  
pd.crosstab(titanic.Age, titanic.Survived, normalize='index').mul(100)
# Out:
# Survived           0           1
# Age
# 0.42        0.000000  100.000000
# 0.67        0.000000  100.000000
# 0.75        0.000000  100.000000
# 0.83        0.000000  100.000000
# 0.92        0.000000  100.000000
# 1.00       28.571429   71.428571
# 2.00       70.000000   30.000000
# 3.00       16.666667   83.333333
# 4.00       30.000000   70.000000
# 5.00        0.000000  100.000000
# 6.00       33.333333   66.666667
# 7.00       66.666667   33.333333
# 8.00       50.000000   50.000000
# 9.00       75.000000   25.000000
# 10.00     100.000000    0.000000
# 11.00      75.000000   25.000000
# 12.00       0.000000  100.000000
# 13.00       0.000000  100.000000
# 14.00      50.000000   50.000000
# 14.50     100.000000    0.000000
# 15.00      20.000000   80.000000
# 16.00      64.705882   35.294118
# 17.00      53.846154   46.153846
# 18.00      65.384615   34.615385
# 19.00      64.000000   36.000000
# 20.00      80.000000   20.000000
# 20.50     100.000000    0.000000
# 21.00      79.166667   20.833333
# 21.75      40.476190   59.523810
# 22.00      59.259259   40.740741
# ...              ...         ...
# 44.00      66.666667   33.333333
# 45.00      58.333333   41.666667
# 45.50     100.000000    0.000000
# 46.00     100.000000    0.000000
# 47.00      88.888889   11.111111
# 48.00      33.333333   66.666667
# 49.00      33.333333   66.666667
# 50.00      50.000000   50.000000
# 51.00      71.428571   28.571429
# 52.00      50.000000   50.000000
# 53.00       0.000000  100.000000
# 54.00      62.500000   37.500000
# 55.00      50.000000   50.000000
# 55.50     100.000000    0.000000
# 56.00      50.000000   50.000000
# 57.00     100.000000    0.000000
# 58.00      40.000000   60.000000
# 59.00     100.000000    0.000000
# 60.00      50.000000   50.000000
# 61.00     100.000000    0.000000
# 62.00      50.000000   50.000000
# 63.00       0.000000  100.000000
# 64.00     100.000000    0.000000
# 65.00     100.000000    0.000000
# 66.00     100.000000    0.000000
# 70.00     100.000000    0.000000
# 70.50     100.000000    0.000000
# 71.00     100.000000    0.000000
# 74.00     100.000000    0.000000
# 80.00       0.000000  100.000000
#
# [94 rows x 2 columns]

# %%
Ag=titanic.pivot_table(index="Age",values="Survived") * 100
Ag
# Out:
#          Survived
# Age
# 0.42   100.000000
# 0.67   100.000000
# 0.75   100.000000
# 0.83   100.000000
# 0.92   100.000000
# 1.00    71.428571
# 2.00    30.000000
# 3.00    83.333333
# 4.00    70.000000
# 5.00   100.000000
# 6.00    66.666667
# 7.00    33.333333
# 8.00    50.000000
# 9.00    25.000000
# 10.00    0.000000
# 11.00   25.000000
# 12.00  100.000000
# 13.00  100.000000
# 14.00   50.000000
# 14.50    0.000000
# 15.00   80.000000
# 16.00   35.294118
# 17.00   46.153846
# 18.00   34.615385
# 19.00   36.000000
# 20.00   20.000000
# 20.50    0.000000
# 21.00   20.833333
# 21.75   59.523810
# 22.00   40.740741
# ...           ...
# 44.00   33.333333
# 45.00   41.666667
# 45.50    0.000000
# 46.00    0.000000
# 47.00   11.111111
# 48.00   66.666667
# 49.00   66.666667
# 50.00   50.000000
# 51.00   28.571429
# 52.00   50.000000
# 53.00  100.000000
# 54.00   37.500000
# 55.00   50.000000
# 55.50    0.000000
# 56.00   50.000000
# 57.00    0.000000
# 58.00   60.000000
# 59.00    0.000000
# 60.00   50.000000
# 61.00    0.000000
# 62.00   50.000000
# 63.00  100.000000
# 64.00    0.000000
# 65.00    0.000000
# 66.00    0.000000
# 70.00    0.000000
# 70.50    0.000000
# 71.00    0.000000
# 74.00    0.000000
# 80.00  100.000000
#
# [94 rows x 1 columns]

# %% [raw]
# help(pd.crosstab)

# %%
# 7. What is the survival rate for each port of embarkation?

n =pd.crosstab([titanic.Embarked_C, titanic.Embarked_Q,titanic.Embarked_S], titanic.Survived ,normalize='index').mul(100)
n
# Out:
# Survived                                  0          1
# Embarked_C Embarked_Q Embarked_S
# 0          0          1           66.099071  33.900929
#            1          0           61.038961  38.961039
# 1          0          0           44.642857  55.357143

# %%
# 7. What is the survival rate for each port of embarkation?

Ag=titanic.pivot_table(index=["Embarked_C","Embarked_Q","Embarked_S"],values="Survived") * 100
Ag
# Out:
#                                    Survived
# Embarked_C Embarked_Q Embarked_S
# 0          0          1           33.900929
#            1          0           38.961039
# 1          0          0           55.357143

# %%
# 8. What is the survival rate for children (under 12) in each `Pclass`?
under12 = titanic[titanic['Age']< 12].groupby('Pclass')['Survived'].sum()/titanic[titanic['Age']< 12].groupby('Pclass')['PassengerId'].count() * 100
under12
# Out:
# Pclass
# 1     75.000000
# 2    100.000000
# 3     40.425532
# dtype: float64

# %%
# 11. Does having family on the boat help or hurt your chances of survival? help youar chance 
pd.crosstab([titanic['FamilyCount']>0], titanic.Survived ,normalize='index').mul(100)[1]
# Out:
# FamilyCount
# False    30.353818
# True     50.564972
# Name: 1, dtype: float64

# %%
# 10. Of all the people that died, who had the most expensive ticket? How much did it cost?

titanic[titanic['Survived']==0].sort_values('Fare', ascending=False)
print(' Mr. Charles Alexander and Mr FortuneMarkhad had ticket cost 263.0000  and die ):')
# Out:
#  Mr. Charles Alexander and Mr FortuneMarkhad had ticket cost 263.0000  and die ):

# %% [markdown]
# ## Step 4: Plotting

# %%
# Survaival Rate for each class
classs.plot(kind='barh');
plt.title('Survaival Rate for each class')
plt.ylabel('Classes');
plt.xlabel('Survaival Rate ');

# plt.xticks(color='white');
# plt.yticks(color='white');

# %%
ageclass = sns.FacetGrid(titanic, hue='Survived', aspect=3, legend_out=True)
ageclass.map(sns.kdeplot, "Age", shade=True).add_legend()
ageclass.set(xlim=(0, 90));

# %%
# 'chances of survival by family
s = titanic.groupby('FamilyCount')['Survived'].sum()/titanic.groupby('FamilyCount')['PassengerId'].count() * 100

plt.title('chances of survival by family');
plt.xlabel('Rate of survival')
plt.ylabel('family  count')

# plt.xticks(color='white')
# plt.yticks(color='white')


s.plot(kind='barh',figsize=(12,8));

# %%
# urvival under 12 by class
under12.plot(kind='barh',figsize=(12,8));
plt.title('survival under 12 by class');
plt.xlabel('Rate of survival')
plt.ylabel('Class')

# plt.xticks(color='white')
# plt.yticks(color='white');
# Out:
# Text(0,0.5,'Class')

# %%
# two barchart to show the survival rate and count 
titanic.groupby('Survived')['Sex_female'].sum().plot(kind='bar')

plt.xticks(rotation=0);
sx.plot(kind='bar')
plt.xticks(rotation=0);
plt.title('survival by gender ',color='k');
plt.xlabel('Gender 0=male ,1=female',color='k')
plt.ylabel('survival rate')

# plt.xticks(color='white')
# plt.yticks(color='white');
# Out:
# Text(0,0.5,'survival rate')

# %%
# two barchart to show the survival rate and count 

titanic.groupby('Survived')['Embarked_C','Embarked_S' ,'Embarked_Q'].sum().plot(kind='bar')
plt.xticks(rotation=0);
n.plot(kind='barh');

# %%
titanic['Fare'].skew()
# Out:
# 4.787316519674893

# %%
titanic.corr()
# Out:
#                        PassengerId  Survived    Pclass       Age     SibSp  \
# Passenger
# Age_group_Infant                -0.007640
# Age_group_Child                 -0.005695
# Age_group_Teenager              -0.009788
# Age_group_Young Adult            0.028707
# Age_group_Adult                 -0.018962
# Age_group_Senior                -0.005333
# Title_Capt                      -0.001124
# Title_Col                       -0.001590
# Title_Don                       -0.001124
# Title_Dr                        -0.002983
# Title_Jonkheer                  -0.001124
# Title_Lady                      -0.001124
# Title_Major                     -0.001590
# Title_Master                    -0.007267
# Title_Miss                      -0.016983
# Title_Mlle                      -0.001590
# Title_Mme                       -0.001124
# Title_Mr                        -0.039411
# Title_Mrs                       -0.013541
# Title_Ms                        -0.001124
# Title_Sir                       -0.001124
# Title_the Countess               1.000000
#
# [36 rows x 36 columns]

# %%
titanic['Fare'].kurt()
# Out:
# 33.39814088089868

# %%
titanic.std()
# Out:
# PassengerId              257.353842
# Survived                   0.486592
# Pclass                     0.836071
# Age                       13.281103
# SibSp                      1.102743
# Parch                      0.806057
# Fare                      49.693429
# FamilyCount                1.613459
# IsReverend                 0.081830
# Sex_female                 0.477990
# Sex_male                   0.477990
# Embarked_C                 0.391372
# Embarked_Q                 0.281141
# Embarked_S                 0.446751
# Age_group_Infant           0.216787
# Age_group_Child            0.165232
# Age_group_Teenager         0.269207
# Age_group_Young Adult      0.494332
# Age_group_Adult            0.428790
# Age_group_Senior           0.155270
# Title_Capt                 0.033501
# Title_Col                  0.047351
# Title_Don                  0.033501
# Title_Dr                   0.088337
# Title_Jonkheer             0.033501
# Title_Lady                 0.033501
# Title_Major                0.047351
# Title_Master               0.207186
# Title_Miss                 0.403390
# Title_Mlle                 0.047351
# Title_Mme                  0.033501
# Title_Mr                   0.493796
# Title_Mrs                  0.347485
# Title_Ms                   0.033501
# Title_Sir                  0.033501
# Title_the Countess         0.033501
# dtype: float64

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.318643    0.523008
# std     257.353842    0.486592    0.836071   13.281103    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   21.750000    0.000000
# 50%     446.000000    0.000000    3.000000   26.507589    0.000000
# 75%     668.500000    1.000000    3.000000   36.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  FamilyCount  IsReverend  Sex_female  \
# count  891.000000  891.000000   891.000000  891.000000  891.000000
# mean     0.381594   32.204208     0.904602    0.006734    0.352413
# std      0.806057   49.693429     1.613459    0.081830    0.477990
# min      0.000000    0.000000     0.000000    0.000000    0.000000
# 25%      0.000000    7.910400     0.000000    0.000000    0.000000
# 50%      0.000000   14.454200     0.000000    0.000000    0.000000
# 75%      0.000000   31.000000     1.000000    0.000000    1.000000
# max      6.000000  512.329200    10.000000    1.000000    1.000000
#
#               ...          Title_Major  Title_Master  Title_Miss  Title_Mlle  \
# count         ...           891.000000    891.000000  891.000000  891.000000
# mean          ...             0.002245      0.044893    0.204265    0.002245
# std           ...             0.047351      0.207186    0.403390    0.047351
# min           ...             0.000000      0.000000    0.000000    0.000000
# 25%           ...             0.000000      0.000000    0.000000    0.000000
# 50%           ...             0.000000      0.000000    0.000000    0.000000
# 75%           ...             0.000000      0.000000    0.000000    0.000000
# max           ...             1.000000      1.000000    1.000000    1.000000
#
#         Title_Mme    Title_Mr   Title_Mrs    Title_Ms   Title_Sir  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.001122    0.580247    0.140292    0.001122    0.001122
# std      0.033501    0.493796    0.347485    0.033501    0.033501
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      0.000000    1.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        Title_the Countess
# count          891.000000
# mean             0.001122
# std              0.033501
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max              1.000000
#
# [8 rows x 36 columns]

# %%
# the oldest person  died? 
old=titanic[titanic['Survived']==0].sort_values('Age', ascending=False).head(1) 
print(f'{old.Name}')
# Out:
# 851    Svensson, Mr. Johan
# Name: Name, dtype: object

# %%
# the youngest person  survived ? 

young=titanic[titanic['Survived']==1].sort_values('Age', ascending=False).head(1)
print(f'{young.Name}')
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
titanic.groupby('Survived')['Age'].max().plot(kind='bar',figsize=(12,8));

# %%
titanic.groupby('Survived')['Age'].min().plot(kind='bar',figsize=(12,8)).plot(kind='bar');

# %%
# to show the age for survival both m/w 
sns.violinplot(x=titanic.Sex_male, y=titanic.Age, hue="Survived", data=titanic,legend=False)
# but the legend out side the graph
plt.legend(title='Survival', bbox_to_anchor=(1.05, 1),loc='upper left');

# %%
sns.violinplot(x=titanic.Pclass, y=titanic.Fare, hue=titanic.Survived, data=titanic);

# %%
# pie chart to show the prcentege of survival  for Embarked_S soory ):
titanic.groupby('Survived')['Embarked_S'].sum().plot(kind='pie',autopct='%1.1f%%');

# %%
# pie chart to show the prcentege of survival  for Embarked_C

titanic.groupby('Survived')['Embarked_C'].sum().plot(kind='pie',autopct='%1.1f%%');

# %%
# pie chart to show the prcentege of survival  for Embarked_Q

titanic.groupby('Survived')['Embarked_Q'].sum().plot(kind='pie',autopct='%1.1f%%');

# %%
# to check for rev survival using Bokeh libary 
output_file('vbar.html')

p = figure(plot_width=400, plot_height=400)
p.vbar(x=titanic.Survived, width=0.5, bottom=0,
       top=titanic.IsReverend, color="firebrick")

show(p)

# %%
# boxplot to see survivar and fare  we can see the outliers 
sns.boxplot(x="Fare", y="Survived", data=titanic, orient='h');

# %%
# see the fair and age 
sns.regplot(data=titanic,
         x=titanic.Age,
             y=titanic.Fare,scatter_kws={"color": "orange"}, line_kws={"color": "blue"});

# %%
g = sns.catplot("Pclass", 'Survived', "Sex_male", data=titanic, kind="bar")

# %%
sns.pointplot(x = "Sex_female", y = "Survived", hue = "Pclass", data = titanic);

# %%
sns.stripplot(x=titanic.Pclass,y=titanic.Fare,hue='Sex_male',jitter=True,data=titanic);

# %%
faresurvival = sns.FacetGrid(titanic, hue="Survived", aspect=2)
faresurvival.map(sns.kdeplot, "Fare", shade=True).add_legend()
faresurvival.set(xlim=(0, 500));

# %%
sns.swarmplot(x ="Fare", y='Survived', data=titanic, orient='h', color='r',);

# %%
# survival rate for majors 
major=titanic.pivot_table(index="Title_Major",values="Survived") * 100
major.plot(kind='bar');

# %%
# survival rate for dactors  
dr=titanic.pivot_table(index="Title_Dr",values="Survived") * 100
dr.plot(kind='bar');

# %%
# survival rate for children  
child=titanic.pivot_table(index="Age_group_Child",values="Survived") * 100
child.plot(kind='bar'); 

# for infait
sns.catplot("Age_group_Infant", 'Survived', "Pclass", data=titanic, kind="bar");
